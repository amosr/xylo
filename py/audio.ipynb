# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyaudio
import numpy as np
import matplotlib.pyplot as plt

import scipy
import wave
import math
import os

# %%
import xylo.audio as xaudio

# %%
vs = xaudio.read_samples(5.0)
xaudio.plot_spectrum(vs, height = 5, distance = 1000, prominence = 5)
# Out:
# [  85.   462.   666.  1025.2 1323.8 1601.4 1824.2 2081.2 2402.8 3400.2
#  4286. ] [ 1.          5.43529412  7.83529412 12.06117647 15.57411765 18.84
#  21.46117647 24.48470588 28.26823529 40.00235294 50.42352941]
# {'peak_heights': array([131.70035504,   6.78860155,   9.4255742 ,  20.43592948,
#         25.41452846,  22.31803442,  21.93191053,  27.5414262 ,
#         16.32990607,   6.72647475,  19.36659335]), 'prominences': array([131.69003238,   6.70880869,   9.28607531,  20.2448073 ,
#         25.370235  ,  22.09520317,  21.51696168,  27.52116046,
#         15.79556243,   6.70361669,  19.34986471]), 'left_bases': array([   16,  1055,  1055,  1055,  1055,  7121,  8303,  1055, 11355,
#        13667, 17699]), 'right_bases': array([38847,  2325,  4088,  5727,  8303,  8303, 10224, 38847, 17699,
#        17699, 38847])}

# %%
xaudio.write_wave('xxxtonebar-300-postdrill6-centre.wav', vs)

# %%
tb204_38_19 = xaudio.read_wave('tonebar-204-38-19.wav')
tb295_40_19 = xaudio.read_wave('tonebar-295x298-40-19.wav')
tb300_40_19_rounded = xaudio.read_wave('tonebar-300-40-19-rounded.wav')
tb300_38_19_noround = xaudio.read_wave('tonebar-300-38-19-noround.wav')

# %%
xaudio.plot_spectrum(tb300_38_19_noround, height = 10, distance = 5000, prominence = 2)
# Out:
# [1081.6 2677.8 4615. ] [1.         2.47577663 4.26682692]
# {'peak_heights': array([279.06007162,  68.99590434,  16.06490511]), 'prominences': array([279.05762309,  68.84694953,  16.0200974 ]), 'left_bases': array([    0,  6019, 19690]), 'right_bases': array([39254, 39254, 39254])}

# %%
xaudio.list_spectrum(height = 10, distance = 1000, prominence = 5, dir='data/wav/')
# Out:
# tonebar-204-38-19-raw.wav
# [1479.6 1921.6 2160.4 2415.8] [1.         1.29872939 1.46012436 1.63273858]
# tonebar-295x298-40-19-raw.wav
# [1048.  1336.8 1611.2 1967.4 2218.6 2631.6 3769.6] [1.         1.27557252 1.53740458 1.87729008 2.11698473 2.5110687
#  3.59694656]
# tonebar-300-postdrill4.5.wav
# [ 655.  1113.2 1774.6 2018.6 2272.8] [1.         1.69954198 2.70931298 3.08183206 3.46992366]
# tonebar-300-predrill.wav
# [ 667.6 1159.2 1767.8 1983.4] [1.         1.73636908 2.64799281 2.97094068]
# tonebar-300-predrill2.wav
# [  93.6  656.4 1281.8 1551.6 1770.2 1975.2] [ 1.          7.01282051 13.69444444 16.57692308 18.91239316 21.1025641 ]
# tonebar-61-cut3-centre.wav
# [ 993.6 1253.4 1514.4 1809.4 2039.  2640.2] [1.         1.26147343 1.52415459 1.82105475 2.05213366 2.65720612]
# tonebar-61-cut3-corner.wav
# [ 994.4 2043.4 2427.  2637. ] [1.         2.05490748 2.44066774 2.65185036]
# tonebar-61-cut3.5-centre.wav
# [ 982.4 1367.6 2058.4] [1.         1.39210098 2.09527687]
# tonebar-61-cut3.5-corner.wav
# [  44.6  420.   724.6  982.  1455.4 2055.  2412.4 2658.2 3275.4] [ 1.          9.41704036 16.24663677 22.01793722 32.632287   46.07623318
#  54.0896861  59.60089686 73.43946188]
# tonebar-61-cut4-centre.wav
# [ 949.6 1168.4 1369.8 1670.6 2030.8 4670.2] [1.         1.23041281 1.44250211 1.75926706 2.13858467 4.91807077]
# tonebar-61-cut4-corner.wav
# [  43.6  949.8 1456.4 2032.8 2597.4] [ 1.         21.78440367 33.40366972 46.62385321 59.5733945 ]
# tonebar-61-cut4.5-centre.wav
# [ 945.6 1166.2 1372.8 2039.6] [1.         1.23329103 1.45177665 2.15693739]
# tonebar-61-cut4.5-corner.wav
# [  28.   422.2  943.8 1436.2 1823.6 2032.6 2582.2] [ 1.         15.07857143 33.70714286 51.29285714 65.12857143 72.59285714
#  92.22142857]
# tonebar-61-cut5-centre.wav
# [ 880. 2512.] [1.         2.85454545]
# tonebar-61-cut5-corner.wav
# [  44.2  897.  1379.2 1597.6 1806.  2010.6 2509.8 3276. ] [ 1.         20.29411765 31.20361991 36.14479638 40.85972851 45.48868778
#  56.78280543 74.11764706]
