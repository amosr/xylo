# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyaudio
import numpy as np
import matplotlib.pyplot as plt

import scipy
import wave
import math
import os

# %%
import xylo.audio as xaudio

# %%
vs = xaudio.read_samples(5.0)
xaudio.plot_spectrum(vs, height = 0.02, distance = 1000, prominence = 0.02)
# Out:
# [  59.6  400.   636.8  973.6 1907.  2157.4 2366. ] [  59.6  400.   636.8  973.6 1907.  2157.4 2366. ]
# {'peak_heights': array([0.07240316, 0.05958637, 0.04928828, 0.04276978, 0.02085592,
#        0.05931512, 0.02667508]), 'prominences': array([0.07239719, 0.05955589, 0.0491723 , 0.04272777, 0.02020827,
#        0.05928483, 0.02641229]), 'left_bases': array([   32,  1872,  2878,  4689,  7765,  4689, 11603]), 'right_bases': array([32371, 32371,  4689,  7765,  9652, 32371, 32371])}

# %%
xaudio.write_wave('tonebar-300-round-corner-2.wav', vs)

# %%
tb204_38_19 = xaudio.read_wave('tonebar-204-38-19.wav')
tb295_40_19 = xaudio.read_wave('tonebar-295x298-40-19.wav')
tb300_40_19_rounded = xaudio.read_wave('tonebar-300-40-19-rounded.wav')
tb300_38_19_noround = xaudio.read_wave('tonebar-300-38-19-noround.wav')

# %%
xaudio.plot_spectrum(tb300_38_19_noround, height = 10, distance = 5000, prominence = 2)
# Out:
# [1081.6 2677.8 4615. ] [1.         2.47577663 4.26682692]
# {'peak_heights': array([279.06007162,  68.99590434,  16.06490511]), 'prominences': array([279.05762309,  68.84694953,  16.0200974 ]), 'left_bases': array([    0,  6019, 19690]), 'right_bases': array([39254, 39254, 39254])}

# %%
xaudio.list_spectrum(height = 0.02, distance = 1000, prominence = 0.01, dir='data/wav/')
# Out:
# tonebar-rawiter2-45-center.wav.wav
# [ 646.75 1140.25 1672.5  2628.75 3043.  ] [ 646.75 1140.25 1672.5  2628.75 3043.  ]
# tonebar-rawiter2-45-corner.wav.wav
# [ 651.25 1671.5  2650.  ] [ 651.25 1671.5  2650.  ]
# tonebar-rawiter2-46-center.wav.wav
# [ 694.25 1201.75 1780.75 3214.  ] [ 694.25 1201.75 1780.75 3214.  ]
# tonebar-rawiter2-46-corner.wav.wav
# [ 695.25 1204.75 1779.5  3218.25] [ 695.25 1204.75 1779.5  3218.25]
# tonebar-rawiter2-47-center.wav.wav
# [ 693.75 1792.5  3220.5 ] [ 693.75 1792.5  3220.5 ]
# tonebar-rawiter2-47-corner.wav.wav
# [ 691.75 1189.5  1801.25] [ 691.75 1189.5  1801.25]
# tonebar-rawiter2-48-center.wav.wav
# [ 683.5  1796.25 3279.25] [ 683.5  1796.25 3279.25]
# tonebar-rawiter2-48-corner.wav.wav
# [ 686. 1798.] [ 686. 1798.]
# tonebar-rawiter2-49-center.wav.wav
# [ 683.25 1799.   3314.25] [ 683.25 1799.   3314.25]
# tonebar-rawiter2-49-corner.wav.wav
# [ 684.75 1215.25 1802.75 3313.25] [ 684.75 1215.25 1802.75 3313.25]
# tonebar-rawiter2-50-center.wav.wav
# [ 713.   1280.75 1817.25 3333.5 ] [ 713.   1280.75 1817.25 3333.5 ]
# tonebar-rawiter2-50-corner.wav
# [  92.5   710.75 1323.5  1817.75] [  92.5   710.75 1323.5  1817.75]
# tonebar-rawiter2-51-center.wav.wav
# [ 762.   1324.25 3535.25] [ 762.   1324.25 3535.25]
# tonebar-rawiter2-51-corner.wav
# [ 763.5  1335.5  1978.25 3518.75] [ 763.5  1335.5  1978.25 3518.75]
# tonebar-rawiter2-52-center.wav
# [ 842.5 2157.5] [ 842.5 2157.5]
# tonebar-rawiter2-52-corner.wav
# [ 845.   2158.25] [ 845.   2158.25]
# tonebar-rawiter2-53-center.wav
# [ 875.   1285.25 2229.5 ] [ 875.   1285.25 2229.5 ]
# tonebar-rawiter2-53-corner.wav
# [ 877.5 2227. ] [ 877.5 2227. ]
# tonebar-rawiter2-54-center.wav
# [898.75] [898.75]
# tonebar-rawiter2-54-corner.wav
# [ 897.25 2271.5 ] [ 897.25 2271.5 ]
# tonebar-rawiter2-55-center.wav
# [ 882.5 2264. ] [ 882.5 2264. ]
# tonebar-rawiter2-55-corner.wav
# [ 121.    885.75 1648.5  2258.5 ] [ 121.    885.75 1648.5  2258.5 ]
# tonebar-rawiter2-56-center.wav
# [ 836.   2169.75] [ 836.   2169.75]
# tonebar-rawiter2-56-corner.wav
# [ 837.75 1394.75 1654.   2170.75 3907.75] [ 837.75 1394.75 1654.   2170.75 3907.75]
# tonebar-rawiter2-56-corner_001.wav
# [  84.    838.75 1365.75 1664.   2170.  ] [  84.    838.75 1365.75 1664.   2170.  ]
# tonebar-rawiter2-75-center.wav.wav
# [1977.25] [1977.25]
# tonebar-rawiter2-77-center.wav.wav
# [2006.75 2445.5 ] [2006.75 2445.5 ]
# tonebar-rawiter2-80-center.wav.wav
# [  77.25 2661.25] [  77.25 2661.25]
# xxxtonebar-86-fullcut0.5-corner.wav
# [  31.2 1029.8 1409.2 1635.2 1838.2 2073.  2396.6 2870.4 3119.4 3723.2] [  31.2 1029.8 1409.2 1635.2 1838.2 2073.  2396.6 2870.4 3119.4 3723.2]
