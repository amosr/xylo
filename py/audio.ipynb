# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyaudio
import numpy as np
import matplotlib.pyplot as plt

import scipy
import wave
import math
import os

# %%
import xylo.audio as xaudio

# %%
vs = xaudio.read_samples(5.0)

# %%
len(vs), np.min(vs), np.max(vs), np.mean(vs)
# Out:
# (220500, -0.2301887, 0.21357435, -2.2830925e-06)

# %%
xaudio.plot_spectrum(vs, height = 5, distance = 2000, prominence = 5)
# xaudio.plot_spectrum(vs, height = 20, distance = 1000, prominence = 2)
# Out:
# [  82.2  689.8 1221.8 1835.6] [ 1.          8.39172749 14.86374696 22.33090024]
# {'peak_heights': array([13.26391007, 72.58981473, 22.92003097, 62.10730087]), 'prominences': array([13.21995124, 72.5802977 , 22.85174507, 62.05510005]), 'left_bases': array([  31,   31, 5352, 7698]), 'right_bases': array([ 2266, 34698,  7698, 34698])}

# %%
xaudio.write_wave('tonebar-300-38-19-C4-rubbermallet.wav', vs)

# %%
tb204_38_19 = xaudio.read_wave('tonebar-204-38-19.wav')
tb295_40_19 = xaudio.read_wave('tonebar-295x298-40-19.wav')
tb300_40_19_rounded = xaudio.read_wave('tonebar-300-40-19-rounded.wav')
tb300_38_19_noround = xaudio.read_wave('tonebar-300-38-19-noround.wav')

# %%
xaudio.plot_spectrum(tb300_38_19_noround, height = 10, distance = 5000, prominence = 2)
# Out:
# [1081.6 2677.8 4615. ] [1.         2.47577663 4.26682692]
# {'peak_heights': array([279.06007162,  68.99590434,  16.06490511]), 'prominences': array([279.05762309,  68.84694953,  16.0200974 ]), 'left_bases': array([    0,  6019, 19690]), 'right_bases': array([39254, 39254, 39254])}

# %%
xaudio.list_spectrum(height = 10, distance = 1000, prominence = 5)
# Out:
# tonebar-204-38-19-raw.wav
# [1479.6 1921.6 2160.4 2415.8] [1.         1.29872939 1.46012436 1.63273858]
# tonebar-295x298-40-19-raw.wav
# [1048.  1336.8 1611.2 1967.4 2218.6 2631.6 3769.6] [1.         1.27557252 1.53740458 1.87729008 2.11698473 2.5110687
#  3.59694656]
# tonebar-300-38-19-cut0.2-r2.wav
# [ 134.6  999.6 1358.  1589.  1858.6 2060.2 2535.6 3509.6 4490.4] [ 1.          7.42644874 10.08915305 11.80534918 13.80832095 15.30609212
#  18.83803863 26.07429421 33.36106984]
# tonebar-300-38-19-cut0.2.wav
# [ 133.2  420.   725.2  999.  1247.4 1495.6 1854.  2119.8 2320.6 2521.2
#  2722.4 3022.4 3297.8 3506.4 3880.6 4198.  4448.  4656.2 4881.4 5085.2
#  5415.  5761.8 6301.8 6527.4 6813.2 7034.2] [ 1.          3.15315315  5.44444444  7.5         9.36486486 11.22822823
#  13.91891892 15.91441441 17.42192192 18.92792793 20.43843844 22.69069069
#  24.75825826 26.32432432 29.13363363 31.51651652 33.39339339 34.95645646
#  36.64714715 38.17717718 40.65315315 43.25675676 47.31081081 49.0045045
#  51.15015015 52.80930931]
# tonebar-300-38-19-cut0.4.wav
# [ 218.4  530.6  928.8 1138.8 1447.2 1835.2 2098.  2410.4] [ 1.          2.42948718  4.25274725  5.21428571  6.62637363  8.4029304
#   9.60622711 11.03663004]
# tonebar-300-38-19-cut0.6.wav
# [  52.2  527.2  871.2 1085.4 1346.  1570.4 1801.  2049.8 2276.4] [ 1.         10.09961686 16.68965517 20.79310345 25.78544061 30.08429119
#  34.50191571 39.26819923 43.6091954 ]
# tonebar-300-38-19-cut0.8.wav
# [  75.6  525.   771.4 1009.  1235.4 2063.8] [ 1.          6.94444444 10.2037037  13.34656085 16.34126984 27.2989418 ]
# tonebar-300-38-19-cut1.0-rubbermallet.wav
# [ 188.   687.2 1205.  1824.2] [1.         3.65531915 6.40957447 9.70319149]
# tonebar-300-38-19-cut1.0.wav
# [ 206.6  481.8  688.6 1006.  1212.8 1558.4 1840.8 2100.4 2316.2 2572.8
#  3531. ] [ 1.          2.33204259  3.33301065  4.86931268  5.87028074  7.54307841
#   8.90997096 10.16650532 11.21103582 12.45304937 17.0909971 ]
# tonebar-300-38-19-raw.wav
# [ 214.4 1081.6 1373.2 1585.8 1919.8 2311.6 2677.8 2951.4 3223.2 3527.4
#  4615. ] [ 1.          5.04477612  6.40485075  7.39645522  8.95429104 10.78171642
#  12.48973881 13.76585821 15.03358209 16.45242537 21.52518657]
# tonebar-300-40-19-raw-rounded.wav
# [ 229.   591.6  876.4 1086.6 1341.8 1614.2 1894.  2147.8 2486.  2689.2
#  2895.  3148.4 3399.  3634.2 3843.  4632.2] [ 1.          2.58340611  3.82707424  4.74497817  5.85938865  7.0489083
#   8.27074236  9.3790393  10.8558952  11.74323144 12.6419214  13.74847162
#  14.84279476 15.869869   16.78165939 20.2279476 ]
