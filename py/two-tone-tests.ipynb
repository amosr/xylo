# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

from typing import NamedTuple
from functools import partial
import math
import json

# %%
import xylo
import xylo.types as t
import xylo.cut
import xylo.slicer as s
import xylo.database
import xylo.sweep as xs
import xylo.audio as xaudio
import xylo.tuning

# %%
tuning = xylo.tuning.yamaha_YX500R

# %%
note = 77
# variant = 'A-fifth-31.4mm'
variant = 'B-semitone'
# variant = 'C-good'
# variant = 'D-fresh-196'

# %%
vs = xaudio.read_samples(4.0)
xaudio.plot_spectrum(vs, height = 0.02, distance = 1000, prominence = 0.02, comparison_freq = tuning.note_to_freq(note))
xaudio.write_wave(f'tb-two-tone-{note}-variant-{variant}', vs)
# Out:
# [2231.25] [1.00166533]
# {'peak_heights': array([0.12579965]), 'prominences': array([0.1257877]), 'left_bases': array([1091]), 'right_bases': array([38501])}

# %%
# xaudio.plot_spectrum(vs, height = 0.002, distance = 1000, prominence = 0.002, comparison_freq = tuning.note_to_freq(note))
