# %%
# %load_ext autoreload
# %autoreload 2

# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

from typing import NamedTuple
from functools import partial
import math
import json

# %%
import xylo
import xylo.types as t
import xylo.cut
import xylo.slicer as s
import xylo.database
import xylo.sweep as xs
import xylo.audio as xaudio
import xylo.tuning

# %%
tuning = xylo.tuning.yamaha_YX500R

# %%
note = 45

# %%
vs = xaudio.read_samples(5.0)
xaudio.plot_spectrum(vs, height = 0.02, distance = 1000, prominence = 0.02, comparison_freq = tuning.note_to_freq(note))
xaudio.write_wave(f'tb-coarse-{note}', vs)
# Out:
# [ 361.6 1112.6 2236.6] [1.03074084 3.17146643 6.37542855]
# {'peak_heights': array([0.09732296, 0.07765207, 0.1058586 ]), 'prominences': array([0.09731576, 0.07763834, 0.10585646]), 'left_bases': array([  32, 2510,   32]), 'right_bases': array([ 7828,  7828, 28976])}
# /Users/amos/proj/xylo/xgit/py/xylo/audio.py:44: RuntimeWarning: invalid value encountered in cast
#   i32 = fs.astype('int32')

# %%
xaudio.plot_spectrum(vs, height = 0.002, distance = 1000, prominence = 0.002, comparison_freq = tuning.note_to_freq(note))
# Out:
# [ 169.   396.   659.  1011.4 1286.  1528.  1760.  2111.8 2579.4 2982.
#  3184.  3487.6 4500.6 6613. ] [ 0.40508883  0.94920223  1.57960674  2.42430085  3.08251027  3.6625783
#   4.21867657  5.06193249  6.18275816  7.14778042  7.63196944  8.35969115
#  10.78782715 15.85119783]
# {'peak_heights': array([0.00384009, 0.00613585, 0.26551196, 0.00746026, 0.01391977,
#        0.00239058, 0.01040405, 0.00280521, 0.00661491, 0.00355396,
#        0.02264115, 0.00296392, 0.00254247, 0.00248738]), 'prominences': array([0.00372676, 0.00583717, 0.26550944, 0.00740016, 0.01386291,
#        0.0023591 , 0.01038593, 0.00278477, 0.00658505, 0.0033193 ,
#        0.02262497, 0.00291393, 0.00254107, 0.00248529]), 'left_bases': array([   35,    35,    35,  4698,  4698,  7401,  7401,  9849, 10994,
#        14509, 10994, 16798, 22195, 27954]), 'right_bases': array([  857,  2049, 22195,  6339, 10994,  7651, 10994, 10994, 14509,
#        14933, 22195, 22195, 36012, 36012])}
